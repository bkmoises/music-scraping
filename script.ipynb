# %%
import os
import json
import time
import pandas as pd

from bs4 import BeautifulSoup
from pydantic import BaseModel

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options

from groq import Groq

from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser

# %%
class MusicDetails(BaseModel):
    artist: str
    track: str
    title: str
    original_title: str

# %%
llm = ChatGroq(
    model_name="llama-3.3-70b-versatile",
    temperature=0.7
)

# parser = JsonOutputParser(pydantic_object={
#     "type": "object",
#     "properties": {
#         "artist": {"type": "string"},
#         "track": {"type": "string"},
#         "title": {"type": "string"},
#         "original_title": {"type": "string"},
#     }
# })

parser = JsonOutputParser(pydantic_object=MusicDetails)

prompt = ChatPromptTemplate.from_messages([
    ("system", """Extract music details into JSON with this structure:
        {{
            "artist": "artist name here",
            "track": "track name here",
            "title": "full title here, artist + track",
            "original_title": "original title here"
        }}"""),
    ("user", "{input}")
])

chain = prompt | llm | parser

def chat(description: str) -> dict:
    try:
        chain.invoke({"input": description})
    except:
        return {"artist": "", "track": "", "title": "", "original_title": description}

# %%
def normalize_content(html):
    title_base = []
    soup = bs(html, "html.parser")
    titles = soup.find_all(id="video-title")

    for title in titles:
        title_cell = title.get_text(strip=True)
        
        title_base.append(title_cell)
    
    return title_base

# %%
def get_page_content(url, full=False):
    options = Options()
    options.add_argument("--headless")
    driver = webdriver.Firefox(options=options)
    
    driver.get(url)
    time.sleep(3)
    
    if full:
        last_height = driver.execute_script("return document.documentElement.scrollHeight")

        while True:
            driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
            time.sleep(2)

            new_height = driver.execute_script("return document.documentElement.scrollHeight")
            
            if new_height == last_height:
                break
            
            last_height = new_height
    
    html = driver.page_source
    driver.quit()
    
    return normalize_content(html)

# %%
DOMAIN = 'https://www.youtube.com/'
CHANNEL = '@GreatStonedDragon'
URL = f'{DOMAIN}{CHANNEL}/videos'

# %%
titles = get_page_content(URL, True)

# %%
j_titles = []

for title in titles:
    if '||' in title:
        title = title.rsplit('||', 1)[0]

        response = chat(title)

        j_titles.append(response)
        print(response)
# Out:
# None
# None
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Yo the switch 2 looks tight '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - TAKE ME BACK TO EDEN "}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - RAIN "}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - DYWTYLM "}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - THE APPARITION "}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - ARE YOU REALLY OKAY? "}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - ASCENSIONISM "}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Vore "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'My first time trying to sing '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Aqua Regia "}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Granite "}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - The Summoning "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched LIKE THAT drum playthrough || SLEEP TOKEN '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - CHOKEHOLD "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Getting Stoned with Dragon '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and checked out LOATHE for the first time! || Is It Really You Reaction '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'HAPPY DANKSGIVING! I got a glass slice of pie to blaze with '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - MISSING LIMBS "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Smoke Sesh with Dragon '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - HIGH WATER "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched THE PAIN REMAINS TRILOGY || Lorna Shore '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - TELOMERES "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched VOICE OF BACEPROT || [NOT] Public Property '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and checked out ELEINE for the first time! || NEVER FORGET '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - DESCENDING "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and bumped KUBLAI KHAN TX || MUD '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard || The (evil) River @ The Red Rocks '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched DARKO US || Session IV '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched VOICE OF BACEPROT || SABOTAGE (Beastie Boys Cover) '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched ALKALINE drum playthrough || SLEEP TOKEN '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - DISTRACTION "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched GRINN || Hold the Knife '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and checked out GORE. || Angels Like You '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - ALKALINE "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched more KING GIZZARD & THE LIZARD WIZARD || INTRASPORT '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched GRINN || Easier To Hurt '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "I got baked and listened to a METALLICA cover || VOLBEAT - Don't Tread on Me "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched WILL RAMOS cover SLEEP TOKEN || HYPNOSIS '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched The Big Push || I Shot the Sheriff/Road to Zion '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and checked out ONI || Aura '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and listened to AUDIOSLAVE || Wide Awake '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Fall For Me"}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Rippin' the GRAV BONG "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched FILTH || OPP STOPPERS '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched BERRIED ALIVE || CRANNIBAL '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched BETTER LOVERS || Love as an act of Rebellion '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched JINJER || KAFKA '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched Courtney LaPlante of SPIRIT BOX || Spirit Box '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched SLEEP THEORY || PARALYZED '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - THE LOVE YOU WANT "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched VOICE OF BACEPROT || ENTER SANDMAN '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched HOUSE OF PROTECTION || BEING ONE '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and listened to AUDIOSLAVE || Like a Stone '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out more INDIAN FOLK METAL || BLOODYWOOD - NU DELHI '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched HOUSE OF PROTECTION || LEARN TO FORGET '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched The Big Push || Xbox Marijuana '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I was CATCHING SMOKE while listening to KING GIZZARD AND THE LIZARD WIZARD '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and listened to KUBLAI KHAN TX || ANTPILE 2 '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - LIKE THAT "}
# {'artist': '', 'track': '', 'title': '', 'original_title': "This one's so catchy it's stupid || OUR PROMISE - DECODE "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and checked out new BREAKING BENJAMIN || AWAKEN '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched more REN || Money Ties '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and checked out BILMURI || TOO LATE '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and checked out BILMURI || THE END '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon gets blasted and watches BAD OMENS || ARTIFICIAL SUICIDE '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - MINE "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched more KING GIZZARD & THE LIZARD WIZARD || CONVERGE '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'BEST metal track for SPOOKY SEASON || PARRIS BRIDGE - BODY BAG '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched VOICE OF BACEPROT || BEFORE I FORGET '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Stoner discovers Stoner-core || GOOD TERMS - COUGH '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched THE BIG PUSH || WAR PIGS '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon gets baked and watches COURTNEY LAPLANTE || CIRCLE WITH ME ONE TAKE '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched VOICE OF BACEPROT || KILLING IN THE NAME '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - HYPNOSIS "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon gets baked and watches || BAD OMENS - DETHRONE (Live Performance) '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - ATLANTIC "}
# {'artist': '', 'track': '', 'title': '', 'original_title': "It's about to get groovy! || SEVEN - SKYLINE DIVIDED "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched THE BROWNING || SOUL DRIFT '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out a new band! || LEFTLOVERS - STINKY '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out more WILL RAMOS || RIPTIDE (Feat. The Gnarly Neighbor)  '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched SPIRIT BOX + JINJER || CIRCLE WITH ME '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out VOICE OF BACEPROT || God allow me (please) to play music '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched THE SUMMONING drum breakdown || SLEEP TOKEN DRUMEO '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out SEVEN || PARALLEL '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and checked out JINJER - ROGUE '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'This one left me GRINN-ing! || SILENCE '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked and watched DAUGHTRY || PIECES '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Bloodsport (Album Version) "}
# {'artist': '', 'track': '', 'title': '', 'original_title': '5 games to try while HIGH '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon checks out more RAINBOW KITTEN SURPRISE || It's Called: Freefall "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I got baked with KING GIZZARD & THE LIZARD WIZARD || Magma Live on KEXP '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I turned 30 '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out more INDIAN FOLK METAL || BLOODYWOOD - GADDAAR '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'This 9-year-old covers THE SUMMONING by SLEEP TOKEN and CRUSHES IT! '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - I WANNA DANCE WITH SOMEBODY "}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - WHEN THE PARTY'S OVER "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Easily one of my all time FAVORITE hype tracks || LANiiDAE - MODA 5 '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I went to their hometown || KNOCKED LOOSE - MOSS COVERS ALL//TAKE ME HOME '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon and Bark get BAKED and play SLACKERS CARTS OF GLORY '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon watches ZEV ROSE play HOLY ROLLER || SPIRIT BOX '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out King Gizzard & The Lizard Wizard || GAIA @ Bonnaroo 2022 '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'First Time checking out DARKO US || Dragon Chaser '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - SHELTER "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out DAUGHTRY || NERVOUS '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon and Bark first time watching The Tale of Jenny and Screech - REN '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Blood Sport "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'A smoke sesh with King Bark || REN, BEETLEJUICE BEETLEJUICE & More '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out a new DEALER song! || PEARL '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'I INSTANTLY FELL IN LOVE WITH THIS BAND || SILLY GOOSE - BAD BEHAVIOR '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'YO, EX-FEVER333 UP IN HERE || House of Protection - Pulling Teeth Reaction '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon watches II of SLEEP TOKEN || DARK SIGNS - DRUMEO '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "My man's got PIPES || Slow Dancing in the Dark by JOJI - Will Ramos Cover "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon watches AMIGO THE DEVIL || Quiet as a Rat '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out INDIAN FOLK METAL || BLOODYWOOD - AAJ '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - DRAG ME UNDER "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'First time checking out GRINN (feat. Espera) || All for You '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'New DAUGHTRY is lowkey HEAVY || THE RECKONING '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon blazes to more TOKEN GRASS || SLEEP TOKEN - Take Aim (Bluegrass) '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out King Gizzard & The Lizard Wizard || GILA MONSTER '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon & Bark check out more REN! || KUJO BEAT DOWN '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Say That You Will "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out WILL RAMOS of LORNA SHORE || SLEEP TOKEN - CHOKEHOLD '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out WITCHZ for the first time! || THE MAGICK '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon & Bark check out more REN! || SICK BOI '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out another breakk.away track! || SECRET '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'JINJER is a genre of their own || BAD WATER (LIVE) '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon & Bark check out more REN! || LOSING IT (FISHER Rap Version) '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'KING GIZZARD AND THE LIZARD WIZARD - Crumbling Castle Live on KEXP '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out RAINBOW KITTEN SURPRISE for the FIRST TIME! '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Sugar "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'HE NAILED IT || Drumeo - Metal Drummer Hears Led Zeppelin for the First Time '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "They're back with a whole new FIRE! || THE BROWNING - OMNI (Feat. The Defect) "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'YO NEW SPIRIT BOX IS VICIOUS || SOFT SPINE '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon is TOKIN' grass to TOKEN GRASS || SLEEP TOKEN - HIGHER (Bluegrass Cover) "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'SLEEP TOKEN || THE NIGHT DOES NOT BELONG TO GOD - DRUMEO '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'MANY EYES || THE LIGHT AGE || FULL ALBUM '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'First time checking out REN || Hi Ren '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon watches AMIGO THE DEVIL || Cocaine and Abel (Caving in Session) '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Are they worth it? || BLAZY SUSAN - TEA LEAF WRAPS '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out The Warning || Z live at the Pepsi Center DCMX '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'A true drum GOD || SLEEP TOKEN - HIGHER - DRUMEO '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "Dragon watches THE WARNING LIVE || MORE live at MTV's VMA 2023 "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'First Time hearing IN THIS MOMENT || SANCTIFY ME '}
# {'artist': '', 'track': '', 'title': '', 'original_title': "DRAGON'S STRAIN REVIEW || PLATINUM CHERRY - HYBRID "}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'HOLY ROLLER - SPIRIT BOX || Courtney LaPlante Live One Take '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon watches THE WARNING LIVE || SIX FEET DEEP live at Wacken Open Air '}
# {'artist': '', 'track': '', 'title': '', 'original_title': 'Dragon checks out LORNA SHORE || INTO THE EARTH '}

# %%
for title in j_titles:
    print(title)
# Out:
# {"artist": "SLEEP TOKEN", "track": "EUCLID", "title": "SLEEP TOKEN - EUCLID", "original_title": "Dragon is SLEEP TOKIN' || SLEEP TOKEN - EUCLID + more"}
# {"artist": "Sleep Token", "track": "Bluegrass", "title": "Sleep Token - Bluegrass", "original_title": "Bluegrass"}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Yo the switch 2 looks tight '}
# {"artist": "SLEEP TOKEN", "track": "TAKE ME BACK TO EDEN", "title": "SLEEP TOKEN - TAKE ME BACK TO EDEN", "original_title": "TAKE ME BACK TO EDEN"}
# {"artist": "SLEEP TOKEN", "track": "RAIN", "title": "SLEEP TOKEN - RAIN", "original_title": "Dragon is SLEEP TOKIN' || SLEEP TOKEN - RAIN"}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - DYWTYLM "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - THE APPARITION "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - ARE YOU REALLY OKAY? "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - ASCENSIONISM "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Vore "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'My first time trying to sing '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Aqua Regia "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Granite "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - The Summoning "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched LIKE THAT drum playthrough || SLEEP TOKEN '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - CHOKEHOLD "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Getting Stoned with Dragon '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and checked out LOATHE for the first time! || Is It Really You Reaction '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'HAPPY DANKSGIVING! I got a glass slice of pie to blaze with '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - MISSING LIMBS "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Smoke Sesh with Dragon '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - HIGH WATER "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched THE PAIN REMAINS TRILOGY || Lorna Shore '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - TELOMERES "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched VOICE OF BACEPROT || [NOT] Public Property '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and checked out ELEINE for the first time! || NEVER FORGET '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - DESCENDING "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and bumped KUBLAI KHAN TX || MUD '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard || The (evil) River @ The Red Rocks '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched DARKO US || Session IV '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched VOICE OF BACEPROT || SABOTAGE (Beastie Boys Cover) '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched King Gizzard & The Lizard Wizard '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched ALKALINE drum playthrough || SLEEP TOKEN '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - DISTRACTION "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched GRINN || Hold the Knife '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and checked out GORE. || Angels Like You '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - ALKALINE "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched more KING GIZZARD & THE LIZARD WIZARD || INTRASPORT '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched GRINN || Easier To Hurt '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "I got baked and listened to a METALLICA cover || VOLBEAT - Don't Tread on Me "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched WILL RAMOS cover SLEEP TOKEN || HYPNOSIS '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched The Big Push || I Shot the Sheriff/Road to Zion '}
# {"artist": "ONI", "track": "Aura", "title": "ONI - Aura", "original_title": "Got Baked and Checked Out ONI || Aura"}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and listened to AUDIOSLAVE || Wide Awake '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Fall For Me"}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Rippin' the GRAV BONG "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched FILTH || OPP STOPPERS '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched BERRIED ALIVE || CRANNIBAL '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched BETTER LOVERS || Love as an act of Rebellion '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched JINJER || KAFKA '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched Courtney LaPlante of SPIRIT BOX || Spirit Box '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched SLEEP THEORY || PARALYZED '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - THE LOVE YOU WANT "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched VOICE OF BACEPROT || ENTER SANDMAN '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched HOUSE OF PROTECTION || BEING ONE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and listened to AUDIOSLAVE || Like a Stone '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out more INDIAN FOLK METAL || BLOODYWOOD - NU DELHI '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched HOUSE OF PROTECTION || LEARN TO FORGET '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched The Big Push || Xbox Marijuana '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I was CATCHING SMOKE while listening to KING GIZZARD AND THE LIZARD WIZARD '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and listened to KUBLAI KHAN TX || ANTPILE 2 '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - LIKE THAT "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "This one's so catchy it's stupid || OUR PROMISE - DECODE "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and checked out new BREAKING BENJAMIN || AWAKEN '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched more REN || Money Ties '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and checked out BILMURI || TOO LATE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and checked out BILMURI || THE END '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon gets blasted and watches BAD OMENS || ARTIFICIAL SUICIDE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - MINE "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched more KING GIZZARD & THE LIZARD WIZARD || CONVERGE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'BEST metal track for SPOOKY SEASON || PARRIS BRIDGE - BODY BAG '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched VOICE OF BACEPROT || BEFORE I FORGET '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Stoner discovers Stoner-core || GOOD TERMS - COUGH '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched THE BIG PUSH || WAR PIGS '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon gets baked and watches COURTNEY LAPLANTE || CIRCLE WITH ME ONE TAKE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched VOICE OF BACEPROT || KILLING IN THE NAME '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - HYPNOSIS "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon gets baked and watches || BAD OMENS - DETHRONE (Live Performance) '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - ATLANTIC "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "It's about to get groovy! || SEVEN - SKYLINE DIVIDED "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched THE BROWNING || SOUL DRIFT '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out a new band! || LEFTLOVERS - STINKY '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out more WILL RAMOS || RIPTIDE (Feat. The Gnarly Neighbor)  '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched SPIRIT BOX + JINJER || CIRCLE WITH ME '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out VOICE OF BACEPROT || God allow me (please) to play music '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched THE SUMMONING drum breakdown || SLEEP TOKEN DRUMEO '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out SEVEN || PARALLEL '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and checked out JINJER - ROGUE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'This one left me GRINN-ing! || SILENCE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked and watched DAUGHTRY || PIECES '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Bloodsport (Album Version) "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': '5 games to try while HIGH '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon checks out more RAINBOW KITTEN SURPRISE || It's Called: Freefall "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I got baked with KING GIZZARD & THE LIZARD WIZARD || Magma Live on KEXP '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I turned 30 '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out more INDIAN FOLK METAL || BLOODYWOOD - GADDAAR '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'This 9-year-old covers THE SUMMONING by SLEEP TOKEN and CRUSHES IT! '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - I WANNA DANCE WITH SOMEBODY "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - WHEN THE PARTY'S OVER "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Easily one of my all time FAVORITE hype tracks || LANiiDAE - MODA 5 '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I went to their hometown || KNOCKED LOOSE - MOSS COVERS ALL//TAKE ME HOME '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon and Bark get BAKED and play SLACKERS CARTS OF GLORY '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon watches ZEV ROSE play HOLY ROLLER || SPIRIT BOX '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out King Gizzard & The Lizard Wizard || GAIA @ Bonnaroo 2022 '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First Time checking out DARKO US || Dragon Chaser '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - SHELTER "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out DAUGHTRY || NERVOUS '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon and Bark first time watching The Tale of Jenny and Screech - REN '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Blood Sport "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'A smoke sesh with King Bark || REN, BEETLEJUICE BEETLEJUICE & More '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out a new DEALER song! || PEARL '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I INSTANTLY FELL IN LOVE WITH THIS BAND || SILLY GOOSE - BAD BEHAVIOR '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'YO, EX-FEVER333 UP IN HERE || House of Protection - Pulling Teeth Reaction '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon watches II of SLEEP TOKEN || DARK SIGNS - DRUMEO '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "My man's got PIPES || Slow Dancing in the Dark by JOJI - Will Ramos Cover "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon watches AMIGO THE DEVIL || Quiet as a Rat '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out INDIAN FOLK METAL || BLOODYWOOD - AAJ '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - DRAG ME UNDER "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time checking out GRINN (feat. Espera) || All for You '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'New DAUGHTRY is lowkey HEAVY || THE RECKONING '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon blazes to more TOKEN GRASS || SLEEP TOKEN - Take Aim (Bluegrass) '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out King Gizzard & The Lizard Wizard || GILA MONSTER '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon & Bark check out more REN! || KUJO BEAT DOWN '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Say That You Will "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out WILL RAMOS of LORNA SHORE || SLEEP TOKEN - CHOKEHOLD '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out WITCHZ for the first time! || THE MAGICK '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon & Bark check out more REN! || SICK BOI '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out another breakk.away track! || SECRET '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'JINJER is a genre of their own || BAD WATER (LIVE) '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon & Bark check out more REN! || LOSING IT (FISHER Rap Version) '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'KING GIZZARD AND THE LIZARD WIZARD - Crumbling Castle Live on KEXP '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out RAINBOW KITTEN SURPRISE for the FIRST TIME! '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Sugar "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'HE NAILED IT || Drumeo - Metal Drummer Hears Led Zeppelin for the First Time '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "They're back with a whole new FIRE! || THE BROWNING - OMNI (Feat. The Defect) "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'YO NEW SPIRIT BOX IS VICIOUS || SOFT SPINE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is TOKIN' grass to TOKEN GRASS || SLEEP TOKEN - HIGHER (Bluegrass Cover) "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'SLEEP TOKEN || THE NIGHT DOES NOT BELONG TO GOD - DRUMEO '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'MANY EYES || THE LIGHT AGE || FULL ALBUM '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time checking out REN || Hi Ren '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon watches AMIGO THE DEVIL || Cocaine and Abel (Caving in Session) '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Are they worth it? || BLAZY SUSAN - TEA LEAF WRAPS '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out The Warning || Z live at the Pepsi Center DCMX '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'A true drum GOD || SLEEP TOKEN - HIGHER - DRUMEO '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon watches THE WARNING LIVE || MORE live at MTV's VMA 2023 "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First Time hearing IN THIS MOMENT || SANCTIFY ME '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "DRAGON'S STRAIN REVIEW || PLATINUM CHERRY - HYBRID "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'HOLY ROLLER - SPIRIT BOX || Courtney LaPlante Live One Take '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon watches THE WARNING LIVE || SIX FEET DEEP live at Wacken Open Air '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out LORNA SHORE || INTO THE EARTH '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - GODS "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out STMLT! || Antimental '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'THE WARNING - ENTER SANDMAN || Live at Teatro Metropolitan CDMX 08/29/2022 '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'BLESSTHEFALL feat. ALPHA WOLF!?! LETS GO || Drag Me Under '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'A groovy vibe from KING GIZZARD & THE LIZARD WIZARD || IRON LUNG - KEXP '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'YES, YES, YES, MORE BETTER LOVERS, YES || FUTURE MYOPIA '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon watches Austin Archey of LORNA SHORE || TO THE HELL FIRE {Drum Cam} '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - GIVE "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Checking out FEVER 333 || HIGHER POWER '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'CHRIS DAUGHTRY covered CHOKEHOLD by SLEEP TOKEN!?! '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out CHOKE (Music Video) || The Warning '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time checking out OUR PROMISE || PANIC WAVES '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'A HIGH-level overview of INSIDE OUT 2 '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - TAKE AIM "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out SEVEN || DISSOCIATIVE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out THE WARNING LIVE @ POLANDROCK2024 || DISCIPLE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon gets toasted and watches NEW BERRIED ALIVE || BROKEN AND MANGOED '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "First Time checking out AMIGO THE DEVIL || I'm Going To Heaven "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon checks out NEVER EASY || You'd Be Home Now "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First Time watching LORNA SHORE || TO THE HELL FIRE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Yo, MEMPHIS MAY FIRE still goes hard!?! || NECESSARY EVIL '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Country + UNDEROATH = Countrycore? || Mitchell Tenpenny - Demon or Ghost '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Smoking out of GLASS PIRATE SHIP!?! || Daily High Club August 2024 Unboxing '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Higher "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon watches THE WARNING LIVE || Hell You Call a Dream (Pepsi Center DCMX) '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'JINJER just got so much cooler to me || CLOUD FACTORY (LIVE) '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Dark Signs "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon peeps new FALLING IN REVERSE || PREQUEL '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon gets zoinked and watches PRIMUS || DMV '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time seeing THE WARNING LIVE || EVOLVE live at VMA 2023 '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Unboxing & Trying out THE APPARATUS! || Stainless Steel BONG '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time hearing KING GIZZARD & THE LIZARD WIZARD|| DRAGON '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time checking out THE WARNING || AUTOMATIC SUN '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - Levitate "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out SOUL DEFENDER || LOVEBITES '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'BORDERLANDS MOVIE REDEMPTION!?! || BORDERLANDS 4 '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon's Strain Review || PEACH RINGS by FRYD EXTRACTS "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time hearing NUMB || SLEEP THEORY '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Gettin' medicated to react to MEDICATE ME || RAIN CITY DRIVE X DAYSEEKER "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon's Strain Review || PINEAPPLE LIFESAVERS by PIFF "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time checking out JINJER LIVE || Pit of Consciousness Live in Kiev '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - The Offering "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - The Night Doesn't Belong to God "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "First Time gettin' wild on some WILDWOOD WEED || Jim Stafford (1974) "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time checking out LOCKED SHUT || TOOTHACHE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'NOTHING MORE + DISTURBED!?! || ANGEL SONG '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I love this band || STONED MARY - WASTED '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Stoners play CHAINED TOGETHER || #1 - Uh oh '}
# {"artist": "HANABIE", "track": "GIRLS TALK", "title": "HANABIE - GIRLS TALK", "original_title": "GIRLS TALK"}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time checking out TEACHER, TEACHER || JINJER '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'So heavy it rips the fabric of time and space || KUBLAI KHAN - SUPREME RULER '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Most underrated band IMHO || LANiiDAE - Worst Day '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'FIRST FULL ALBUM REACTION || BILMURI - EGGY POCKET '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - THE WAY THAT YOU WERE "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Are these graphics any better? || LOLLIPOP CHAINSAW REPOP TRAILER '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'FIT FOR THE PLOT IN THE KING IN YOU || TECHNIUM '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'BAND-MAID and THE WARNING || SHOW THEM '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "I'VE BEEN WAITING ON THIS NEW MANY EYES SINGLE || HARBINGER "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Are they really worth it? || KING PALM - MAGIC MINT '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - JAWS "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'FRANK WEST IS BACK AND LOOKS BETTER THAN EVER || DEAD RISING DELUXE REMASTER '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Checking out NEMOPHILA for the first time || ZEN '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'BERRIED ALIVE with drum tracks is UNBEATABLE || RAISIN THE DEAD '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon takes HUESTON for a JOY RIDE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'HECK YEA, NEW BETTER LOVERS! || A WHITE HORSE COVERED IN BLOOD '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Stoners in Space || HEAVENLY BODIES - #1 '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "First time hearing SOMEONE'S DAUGHTER || JINJER "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time hearing VORTEX || JINJER '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time hearing KARATE || BABYMETAL (LIVE @ Download 2016) '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - JERICHO "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'THICC THICCLY is actually a thing!?! || Bilmuri ft. Caleb Shomo '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time hearing UNCHAINED || LOVEBITES '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First Time hearing The Dragon Cries || BAND-MAID '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First Time hearing From Now On || BAND-MAID '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Bluegrass SLEEP TOKEN covers!?! || TOKEN GRASS - CHOKEHOLD '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time ever listening to JINJER || PISCES - LIVE SET '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - NAZARETH "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time hearing STUCK IN MY HEAD || SLEEP THEORY '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Get to know GreatStonedDragon '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Checking out ALL GAS || BILMURI '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time hearing HOUSE ON SAND || NOTHING MORE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - CALCUTTA "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time hearing WE ARE THE RESURRECTION || LOVEBITES '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon checks out SPINNIN' YOU AROUND || BILMURI "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First time hearing DOKI DOKI MORNING || BABYMETAL '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - WHEN THE BOUGH BREAKS "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "DRAGON checks out BREAKK.AWAY || I'LL SEE YOU WHEN THE NIGHT COMES "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - FIELDS OF ELATION "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon hates Florida Georgia Line || BILMURI - 2016 CAVALIERS (Ohio) FT. KNOW '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "Dragon is SLEEP TOKIN' || SLEEP TOKEN - THREAD THE NEEDLE "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'DRAGON turns it up! || LIMP BIZKIT - Turn it up, B***h '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'EASILY a new FAVORITE band || PARRIS BRIDGE - DEATHWATCH '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out PROTECT YOU || BAND-MAID '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out THE OFFERING || SLEEP TOKEN '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'GETTING STONED WITH DRAGON || DUDEBEARD '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out DEMONBERRY || BERRIED ALIVE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'DRAGON checks out BE THE GAL || HANABIE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'DRAGON watches HAVOCADO for the first time! || BERRIED ALIVE '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon goes to Kentucky! || #2 Happy 4th of July! '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "DRAGON listens to TALKIN' 2 UR GHOST || BILMURI "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'DRAGON goes to Kentucky! || #1 - We made it! '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon checks out CHOKEHOLD || SLEEP TOKEN '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Dragon watches Miyako Piano Solo La Campanella   Lost in the Garden || LOVEBITES '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'HONEYMOON TATTOOS '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "This one's from another planet || SILENT PLANET - ANUNNAKI "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Ever roll up a ROSE before?! || BLAZY SUSAN - ROSE WRAPS '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'I was BLINDSIDED by this BILMURI visualizer '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'DRAGON ASCENDS || SLEEP TOKEN - ASCENSIONISM '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'DRAGON watches ALONE by BAND-MAID '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'First Time Checking out BERRIED ALIVE || BANANA SPLIT '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'Bilmuri & Dylan Marlowe did not show up EMPTYHANDED '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title':
}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'SELFIE W/ DECEASED AT OPEN CASKET FUNERAL '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'MANY EYES || REVELATION '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "AN ELEVATED BALDUR'S GATE 3 PLAYTHROUGH "}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': 'STONERS PLAY || A HAT IN TIME '}
# {'artist': 'Unkown', 'track': 'Unkown', 'title': 'Unkown', 'original_title': "LET'S PLAY THE MORTUARY ASSISTANT "}

# %%
for title in j_titles:
    for key in ['artist', 'track', 'title']:
        title[key] = title[key].title()

    print(title)
# Out:
#   Cell In[144], line 3
#     print(title)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
df = pd.json_normalize(j_titles)

df
# Out:
#                                artist                       track  \
# 0                   Blood Incantation                The Stargate
# 1                             Unknown                     Unknown
# 2                         The Warning   Queen Of The Murder Scene
# 3                        The Browning            Blue (Da Ba Dee)
# 4                   Breaking Benjamin                      Awaken
# 5  King Gizzard And The Lizard Wizard                    K.G.L.W.
# 6                         Sleep Token                      Euclid
# 7                             Bilmuri  Absolutelycrankinmymfinhog
# 8                         Sleep Token               Missing Limbs
# 9    Bad Omens And Too Close To Touch                    Sympathy
#
#                                            title              original_title
# 0               Blood Incantation - The Stargate                The Stargate
# 1              Until Dawn Movie Trailer Reaction    UNTIL DAWN Movie trailer
# 2        The Warning - Queen Of The Murder Scene   Queen of the Murder Scene
# 3                The Browning - Blue (Da Ba Dee)            Blue (Da Ba Dee)
# 4                     Breaking Benjamin - Awaken  BREAKING BENJAMIN - AWAKEN
# 5  King Gizzard And The Lizard Wizard - K.G.L.W.                    K.G.L.W.
# 6                           Sleep Token - Euclid                      EUCLID
# 7           Bilmuri - Absolutelycrankinmymfinhog  ABSOLUTELYCRANKINMYMFINHOG
# 8                    Sleep Token - Missing Limbs               Missing Limbs
# 9    Bad Omens And Too Close To Touch - Sympathy                    Sympathy

# %%
response.sort()
titles = []

for title in response:
    new_title = None
    baked = 'i got baked'
    
    if baked in title.lower():
        if baked + ' and watched' in title.lower():
            continue
        
        if baked + ' and played' in title.lower():
            continue
        
        if 'live on' in title.lower():
            continue
        
        if 'live at' in title.lower():
            continue
        
        elif 'checked out new' in title.lower():
            new_title = title.split(' new ', maxsplit=1)[-1]
        elif 'checked out' in title.lower():
            new_title = title.split(' out ', maxsplit=1)[-1]
        elif 'reacted to' in title.lower() or 'listened to' in title.lower():
            new_title = title.split(' to ', maxsplit=1)[-1]
        elif 'bumped' in title.lower() or 'listened to' in title.lower():
            new_title = title.split(' bumped ', maxsplit=1)[-1]
        
        if not new_title:
            print(title)
            continue
        
        if '||' in new_title:
            parts = new_title.split('||')
            parts.pop()
            
            new_title = '-'.join(parts)
        
        new_title = new_title.title().replace('!', '')
        new_title = new_title.replace(' For The First Time ', '')
        
        content = {
            "title": title,
            "new_title": new_title.strip()
        }
        
        titles.append(content)
        
        
    
    # print(title)
    
df = pd.json_normalize(titles)

df
# Out:
#                                                 title  \
# 0   I got baked and bumped KUBLAI KHAN TX || MUD |...
# 1   I got baked and checked out BILMURI || THE END...
# 3                                Eleine- Never Forget
# 4                             Gore. - Angels Like You
# 5                      Holy Wars - 21St Century Bitch
# 6                Imminence - Death By A Thousand Cuts
# 7                       Imminence - Heaven Shall Burn
# 8                              Imminence - Temptation
# 9                                      Jinjer - Rogue
# 10                  Loathe- Is It Really You Reaction
# 11                       Not Enough Space - Primitive
# 12                                         Oni - Aura
# 13        Phantom Limbs - Consider That Bridge Burned
# 14                Slift - Ummon (Levitation Sessions)
# 15                             Thecityisours - So Sad
# 16                                    Thornhill  Nerv
# 17                           Xoth - Saga Of The Blade
# 18                         Breaking Benjamin - Awaken
# 19                          Billy Strings - Morbud4Me
# 20                          Audioslave - Like A Stone
# 21                            Audioslave - Wide Awake
# 22                         Kublai Khan Tx - Antpile 2
# 23                                   Shoganai - Ankor
# 24                           Volbeat - Still Counting
# 25    A Metallica Cover - Volbeat - Don'T Tread On Me
# 26                       Actor Observer - Fool'S Gold
# 27                  Acoustic Bad Omens - If I'M There
# 28                               Babymetal - Pa Pa Ya
# 29                        Bad Omens - The Worst In Me
# 30                   Billy Strings - Dust In A Baggie
# 31                   Blood Incantation - The Stargate
# 32                  Bloodywood Ft Babymetal - Bekhauf
# 33            Dead Poet Society Ft The Warning - Hurt
# 34                            Dreamwake - Night Rider
# 35                          Her Last Sight - Serenity
# 36      Kasey Chambers - Lose Yourself (Eminem Cover)
# 37  King Gizzard And The Lizard Wizard - Head On/Pill
# 38  King Gizzard And The Lizard Wizard - Hypertension
# 39      King Gizzard And The Lizard Wizard - K.G.L.W.
# 40      King Gizzard And The Lizard Wizard - Shanghai
# 41        Marshmello Ft A Day To Remember - Rescue Me
# 42                               Nothing More - Stuck
# 43                                   Novelists - Coda
# 44                           Our Promise - Fifty-Five
# 45                               Our Promise - Hijack
# 46                        Paleface Swiss - Deathtouch
# 47              Psychedelic Porn Crumpets - Cornflake
# 48                               Ren - Slaughterhouse
# 49                          Starset - Brave New World
# 50                                   Starset - Toksik
# 51                          Silent Planet - Mindframe
# 52                        The Warning - Enter Sandman
# 53                           Thecityisours - Hot Mess
# 54                  Voice Of Baceprot - Mighty Island
# 55  The Psychedelic Porn Crumpets - Found God In A...

# %%
for item in response:
    ignore = ['trailer', 'movie', 'and watched', 'and played', 'live at', 'live on']
    
    title = item['title'].replace('for the first time', '').replace(' ! ', ' ')
    
    if any(keyword in title.lower() for keyword in ignore):
        continue
    
    if 'i got baked' in title.lower():
        continue
        parts = title.split(' to ', maxsplit=1)
        
        if len(parts) == 1:
            parts = title.split(' out ', maxsplit=1)
            
        if len(parts) == 1:
            parts = title.split(' bumped ', maxsplit=1)
        
        new_title = parts[-1]
        new_parts = new_title.split()
        
        
        if 'greatstone' in new_parts[-1].lower():
            new_parts.pop()
            
            new_title = ' '.join(new_parts)
            
        title = new_title
        
        continue
        
    print(title)

# %%
text = 'JINJER - ROGUE || GreatStonedReactions'

parts = text.split()
# Out:
# JINJER - ROGUE ||
